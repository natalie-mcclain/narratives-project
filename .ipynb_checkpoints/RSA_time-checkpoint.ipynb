# %%
import h5py

subject_list = [
    "sub-002", "sub-003", "sub-004", "sub-005", "sub-006", "sub-007", "sub-008",
    "sub-009", "sub-010", "sub-011", "sub-012", "sub-013", "sub-014", "sub-015",
    "sub-016", "sub-017", "sub-018", "sub-019", "sub-020", "sub-023", "sub-024",
    "sub-025", "sub-026", "sub-027", "sub-028", "sub-029", "sub-030", "sub-031",
    "sub-032", "sub-033", "sub-034", "sub-035", "sub-036", "sub-037", "sub-039",
    "sub-040", "sub-041", "sub-042", "sub-043", "sub-044", "sub-045", "sub-046",
    "sub-047", "sub-048", "sub-049", "sub-050", "sub-051", "sub-052", "sub-053",
    "sub-054", "sub-055", "sub-057", "sub-058", "sub-059", "sub-060", "sub-061",
    "sub-062", "sub-063", "sub-064", "sub-065", "sub-066", "sub-067", "sub-070",
    "sub-071", "sub-072", "sub-073", "sub-074", "sub-075", "sub-076", "sub-077",
    "sub-078", "sub-079", "sub-080", "sub-081", "sub-082"
]

# Dictionary to store timeseries data per subject
timeseries_dict = {}

# Variable to store networks once
networks = None

for subj in subject_list:
    file_path = f'shirer_components/{subj}_desc-shirercomponents.h5'
    
    print(f"\nLoading subject {subj} from: {file_path}")
    
    with h5py.File(file_path, 'r') as f:
        # Load networks only once
        if networks is None:
            networks = f['network'][:]
            print("Loaded networks:", networks)
        
        # Load timeseries and store in dictionary
        data = f['timeseries'][:]
        timeseries_dict[subj] = data
        print(f"Timeseries shape for subject {subj}:", data.shape)
# Out:
# Loading subject sub-002 from: shirer_components/sub-002_desc-shirercomponents.h5
# Loaded networks: [b'anteriorsalience' b'auditory' b'basalganglia' b'dorsaldmn'
#  b'highervisual' b'language' b'leftcontrol' b'posteriorsalience'
#  b'precuneus' b'primaryvisual' b'rightcontrol' b'sensorimotor'
#  b'ventraldmn' b'visuospatial']
# Timeseries shape for subject sub-002: (14, 279)
#
# Loading subject sub-003 from: shirer_components/sub-003_desc-shirercomponents.h5
# Timeseries shape for subject sub-003: (14, 279)
#
# Loading subject sub-004 from: shirer_components/sub-004_desc-shirercomponents.h5
# Timeseries shape for subject sub-004: (14, 279)
#
# Loading subject sub-005 from: shirer_components/sub-005_desc-shirercomponents.h5
# Timeseries shape for subject sub-005: (14, 279)
#
# Loading subject sub-006 from: shirer_components/sub-006_desc-shirercomponents.h5
# Timeseries shape for subject sub-006: (14, 279)
#
# Loading subject sub-007 from: shirer_components/sub-007_desc-shirercomponents.h5
# Timeseries shape for subject sub-007: (14, 279)
#
# Loading subject sub-008 from: shirer_components/sub-008_desc-shirercomponents.h5
# Timeseries shape for subject sub-008: (14, 279)
#
# Loading subject sub-009 from: shirer_components/sub-009_desc-shirercomponents.h5
# Timeseries shape for subject sub-009: (14, 279)
#
# Loading subject sub-010 from: shirer_components/sub-010_desc-shirercomponents.h5
# Timeseries shape for subject sub-010: (14, 279)
#
# Loading subject sub-011 from: shirer_components/sub-011_desc-shirercomponents.h5
# Timeseries shape for subject sub-011: (14, 279)
#
# Loading subject sub-012 from: shirer_components/sub-012_desc-shirercomponents.h5
# Timeseries shape for subject sub-012: (14, 279)
#
# Loading subject sub-013 from: shirer_components/sub-013_desc-shirercomponents.h5
# Timeseries shape for subject sub-013: (14, 279)
#
# Loading subject sub-014 from: shirer_components/sub-014_desc-shirercomponents.h5
# Timeseries shape for subject sub-014: (14, 279)
#
# Loading subject sub-015 from: shirer_components/sub-015_desc-shirercomponents.h5
# Timeseries shape for subject sub-015: (14, 279)
#
# Loading subject sub-016 from: shirer_components/sub-016_desc-shirercomponents.h5
# Timeseries shape for subject sub-016: (14, 279)
#
# Loading subject sub-017 from: shirer_components/sub-017_desc-shirercomponents.h5
# Timeseries shape for subject sub-017: (14, 279)
#
# Loading subject sub-018 from: shirer_components/sub-018_desc-shirercomponents.h5
# Timeseries shape for subject sub-018: (14, 279)
#
# Loading subject sub-019 from: shirer_components/sub-019_desc-shirercomponents.h5
# Timeseries shape for subject sub-019: (14, 279)
#
# Loading subject sub-020 from: shirer_components/sub-020_desc-shirercomponents.h5
# Timeseries shape for subject sub-020: (14, 279)
#
# Loading subject sub-023 from: shirer_components/sub-023_desc-shirercomponents.h5
# Timeseries shape for subject sub-023: (14, 279)
#
# Loading subject sub-024 from: shirer_components/sub-024_desc-shirercomponents.h5
# Timeseries shape for subject sub-024: (14, 279)
#
# Loading subject sub-025 from: shirer_components/sub-025_desc-shirercomponents.h5
# Timeseries shape for subject sub-025: (14, 279)
#
# Loading subject sub-026 from: shirer_components/sub-026_desc-shirercomponents.h5
# Timeseries shape for subject sub-026: (14, 279)
#
# Loading subject sub-027 from: shirer_components/sub-027_desc-shirercomponents.h5
# Timeseries shape for subject sub-027: (14, 279)
#
# Loading subject sub-028 from: shirer_components/sub-028_desc-shirercomponents.h5
# Timeseries shape for subject sub-028: (14, 279)
#
# Loading subject sub-029 from: shirer_components/sub-029_desc-shirercomponents.h5
# Timeseries shape for subject sub-029: (14, 279)
#
# Loading subject sub-030 from: shirer_components/sub-030_desc-shirercomponents.h5
# Timeseries shape for subject sub-030: (14, 279)
#
# Loading subject sub-031 from: shirer_components/sub-031_desc-shirercomponents.h5
# Timeseries shape for subject sub-031: (14, 279)
#
# Loading subject sub-032 from: shirer_components/sub-032_desc-shirercomponents.h5
# Timeseries shape for subject sub-032: (14, 279)
#
# Loading subject sub-033 from: shirer_components/sub-033_desc-shirercomponents.h5
# Timeseries shape for subject sub-033: (14, 279)
#
# Loading subject sub-034 from: shirer_components/sub-034_desc-shirercomponents.h5
# Timeseries shape for subject sub-034: (14, 279)
#
# Loading subject sub-035 from: shirer_components/sub-035_desc-shirercomponents.h5
# Timeseries shape for subject sub-035: (14, 279)
#
# Loading subject sub-036 from: shirer_components/sub-036_desc-shirercomponents.h5
# Timeseries shape for subject sub-036: (14, 279)
#
# Loading subject sub-037 from: shirer_components/sub-037_desc-shirercomponents.h5
# Timeseries shape for subject sub-037: (14, 279)
#
# Loading subject sub-039 from: shirer_components/sub-039_desc-shirercomponents.h5
# Timeseries shape for subject sub-039: (14, 279)
#
# Loading subject sub-040 from: shirer_components/sub-040_desc-shirercomponents.h5
# Timeseries shape for subject sub-040: (14, 279)
#
# Loading subject sub-041 from: shirer_components/sub-041_desc-shirercomponents.h5
# Timeseries shape for subject sub-041: (14, 279)
#
# Loading subject sub-042 from: shirer_components/sub-042_desc-shirercomponents.h5
# Timeseries shape for subject sub-042: (14, 279)
#
# Loading subject sub-043 from: shirer_components/sub-043_desc-shirercomponents.h5
# Timeseries shape for subject sub-043: (14, 279)
#
# Loading subject sub-044 from: shirer_components/sub-044_desc-shirercomponents.h5
# Timeseries shape for subject sub-044: (14, 279)
#
# Loading subject sub-045 from: shirer_components/sub-045_desc-shirercomponents.h5
# Timeseries shape for subject sub-045: (14, 279)
#
# Loading subject sub-046 from: shirer_components/sub-046_desc-shirercomponents.h5
# Timeseries shape for subject sub-046: (14, 279)
#
# Loading subject sub-047 from: shirer_components/sub-047_desc-shirercomponents.h5
# Timeseries shape for subject sub-047: (14, 279)
#
# Loading subject sub-048 from: shirer_components/sub-048_desc-shirercomponents.h5
# Timeseries shape for subject sub-048: (14, 279)
#
# Loading subject sub-049 from: shirer_components/sub-049_desc-shirercomponents.h5
# Timeseries shape for subject sub-049: (14, 279)
#
# Loading subject sub-050 from: shirer_components/sub-050_desc-shirercomponents.h5
# Timeseries shape for subject sub-050: (14, 279)
#
# Loading subject sub-051 from: shirer_components/sub-051_desc-shirercomponents.h5
# Timeseries shape for subject sub-051: (14, 279)
#
# Loading subject sub-052 from: shirer_components/sub-052_desc-shirercomponents.h5
# Timeseries shape for subject sub-052: (14, 279)
#
# Loading subject sub-053 from: shirer_components/sub-053_desc-shirercomponents.h5
# Timeseries shape for subject sub-053: (14, 279)
#
# Loading subject sub-054 from: shirer_components/sub-054_desc-shirercomponents.h5
# Timeseries shape for subject sub-054: (14, 279)
#
# Loading subject sub-055 from: shirer_components/sub-055_desc-shirercomponents.h5
# Timeseries shape for subject sub-055: (14, 279)
#
# Loading subject sub-057 from: shirer_components/sub-057_desc-shirercomponents.h5
# Timeseries shape for subject sub-057: (14, 279)
#
# Loading subject sub-058 from: shirer_components/sub-058_desc-shirercomponents.h5
# Timeseries shape for subject sub-058: (14, 279)
#
# Loading subject sub-059 from: shirer_components/sub-059_desc-shirercomponents.h5
# Timeseries shape for subject sub-059: (14, 279)
#
# Loading subject sub-060 from: shirer_components/sub-060_desc-shirercomponents.h5
# Timeseries shape for subject sub-060: (14, 279)
#
# Loading subject sub-061 from: shirer_components/sub-061_desc-shirercomponents.h5
# Timeseries shape for subject sub-061: (14, 279)
#
# Loading subject sub-062 from: shirer_components/sub-062_desc-shirercomponents.h5
# Timeseries shape for subject sub-062: (14, 279)
#
# Loading subject sub-063 from: shirer_components/sub-063_desc-shirercomponents.h5
# Timeseries shape for subject sub-063: (14, 279)
#
# Loading subject sub-064 from: shirer_components/sub-064_desc-shirercomponents.h5
# Timeseries shape for subject sub-064: (14, 279)
#
# Loading subject sub-065 from: shirer_components/sub-065_desc-shirercomponents.h5
# Timeseries shape for subject sub-065: (14, 279)
#
# Loading subject sub-066 from: shirer_components/sub-066_desc-shirercomponents.h5
# Timeseries shape for subject sub-066: (14, 279)
#
# Loading subject sub-067 from: shirer_components/sub-067_desc-shirercomponents.h5
# Timeseries shape for subject sub-067: (14, 279)
#
# Loading subject sub-070 from: shirer_components/sub-070_desc-shirercomponents.h5
# Timeseries shape for subject sub-070: (14, 279)
#
# Loading subject sub-071 from: shirer_components/sub-071_desc-shirercomponents.h5
# Timeseries shape for subject sub-071: (14, 279)
#
# Loading subject sub-072 from: shirer_components/sub-072_desc-shirercomponents.h5
# Timeseries shape for subject sub-072: (14, 279)
#
# Loading subject sub-073 from: shirer_components/sub-073_desc-shirercomponents.h5
# Timeseries shape for subject sub-073: (14, 279)
#
# Loading subject sub-074 from: shirer_components/sub-074_desc-shirercomponents.h5
# Timeseries shape for subject sub-074: (14, 279)
#
# Loading subject sub-075 from: shirer_components/sub-075_desc-shirercomponents.h5
# Timeseries shape for subject sub-075: (14, 279)
#
# Loading subject sub-076 from: shirer_components/sub-076_desc-shirercomponents.h5
# Timeseries shape for subject sub-076: (14, 279)
#
# Loading subject sub-077 from: shirer_components/sub-077_desc-shirercomponents.h5
# Timeseries shape for subject sub-077: (14, 279)
#
# Loading subject sub-078 from: shirer_components/sub-078_desc-shirercomponents.h5
# Timeseries shape for subject sub-078: (14, 279)
#
# Loading subject sub-079 from: shirer_components/sub-079_desc-shirercomponents.h5
# Timeseries shape for subject sub-079: (14, 279)
#
# Loading subject sub-080 from: shirer_components/sub-080_desc-shirercomponents.h5
# Timeseries shape for subject sub-080: (14, 279)
#
# Loading subject sub-081 from: shirer_components/sub-081_desc-shirercomponents.h5
# Timeseries shape for subject sub-081: (14, 279)
#
# Loading subject sub-082 from: shirer_components/sub-082_desc-shirercomponents.h5
# Timeseries shape for subject sub-082: (14, 279)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import pdist, squareform

# Step 1: Compute RSA per subject
rsa_matrices = []  # list of subject-level RSA matrices

for subj in subject_list:
    data = timeseries_dict[subj]  # shape: (networks, timepoints)
    data = data.T  # shape becomes (timepoints, networks)
    
    # Optional: check and drop timepoints with NaNs
    valid_rows = ~np.isnan(data).any(axis=1)
    data = data[valid_rows, :]
    
    # Compute 1 - correlation distance (similarity)
    dissimilarity = pdist(data, metric='correlation')  # (T * (T-1) / 2,)
    rsa = 1 - squareform(dissimilarity)  # shape: (T, T)
    rsa_matrices.append(rsa)

# Step 2: Pad RSA matrices if needed (if any subjects have fewer TRs)
max_T = max(r.shape[0] for r in rsa_matrices)

rsa_matrices_padded = []
for rsa in rsa_matrices:
    T = rsa.shape[0]
    if T < max_T:
        padded = np.full((max_T, max_T), np.nan)
        padded[:T, :T] = rsa
        rsa_matrices_padded.append(padded)
    else:
        rsa_matrices_padded.append(rsa)

rsa_stack = np.stack(rsa_matrices_padded, axis=0)  # shape: (subjects, T, T)
print("RSA stack shape:", rsa_stack.shape)

# Step 3: Average across subjects
rsa_avg = np.nanmean(rsa_stack, axis=0)

# Step 4: Visualize
plt.figure(figsize=(10, 8))
sns.heatmap(rsa_avg, cmap='viridis', square=True, xticklabels=False, yticklabels=False)
plt.title("Average RSA Across Subjects (Time × Time)")
plt.xlabel("Timepoint")
plt.ylabel("Timepoint")
plt.tight_layout()
plt.show()
# Out:
# RSA stack shape: (75, 279, 279)

# %%
# Index of sub-002 in your list
subj_index = subject_list.index("sub-002")
rsa_example = rsa_matrices[subj_index]

plt.figure(figsize=(10, 8))
sns.heatmap(rsa_example, cmap='viridis', square=True, xticklabels=False, yticklabels=False)
plt.title("RSA for sub-002 (Time × Time)")
plt.xlabel("Timepoint")
plt.ylabel("Timepoint")
plt.tight_layout()
plt.show()

# %%
# Index of sub-002 in your list
subj_index = subject_list.index("sub-025")
rsa_example = rsa_matrices[subj_index]

plt.figure(figsize=(10, 8))
sns.heatmap(rsa_example, cmap='viridis', square=True, xticklabels=False, yticklabels=False)
plt.title("RSA for sub-025 (Time × Time)")
plt.xlabel("Timepoint")
plt.ylabel("Timepoint")
plt.tight_layout()
plt.show()
